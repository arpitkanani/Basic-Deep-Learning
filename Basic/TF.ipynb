# %%
import numpy as np
import pandas as pd

# %%
import tensorflow as tf

# %%
print("tensorflow version: {}".format(tf.__version__))
print("eager Execution :{}".format(tf.executing_eagerly()))
print("keras version :{}".format(tf.keras.__version__))
# Out:
# tensorflow version: 2.20.0
# eager Execution :True
# keras version :3.12.0

# %%
if tf.test.is_gpu_available():
    print("Running on GPU")
else:
    print("running on CPU")
# Out:
# WARNING:tensorflow:From C:\Users\kanan\AppData\Local\Temp\ipykernel_2120\575076766.py:1: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# running on CPU

# %%
ineuron=tf.constant(42)
ineuron
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=42>

# %%
ineuron.numpy()
# Out:
# np.int32(42)

# %%
ineuron1=tf.constant(1,dtype=tf.int64)
ineuron1
# Out:
# <tf.Tensor: shape=(), dtype=int64, numpy=1>

# %%
ineuron_x=tf.constant([[4,2],[9,5]])
print(ineuron_x)
# Out:
# tf.Tensor(
# [[4 2]
#  [9 5]], shape=(2, 2), dtype=int32)

# %%
ineuron_x.numpy()
# Out:
# array([[4, 2],
#        [9, 5]], dtype=int32)

# %%
print("shape",ineuron_x.shape)
print(ineuron_x.dtype)
# Out:
# shape (2, 2)
# <dtype: 'int32'>

# %%
import tensorflow as tf

# %%
variable=tf.Variable([[1,2,3,4],[11,29,12,13]])
checkpoint=tf.train.Checkpoint(var=variable)
save_path=checkpoint.save('./vars')
variable.assign([[0,0,0,0],[0,0,0,0]])
variable
checkpoint.restore(save_path)
print(variable)
# Out:
# <tf.Variable 'Variable:0' shape=(2, 4) dtype=int32, numpy=
# array([[ 1,  2,  3,  4],
#        [11, 29, 12, 13]], dtype=int32)>

# %%
def f1(x,y):
    return tf.reduce_mean(input_tensor=tf.multiply(x**2,5)+y**2)

f2=tf.function(f1)
x=tf.constant([4.,-5.])
y=tf.constant([2.,3.])

assert f1(x,y).numpy()==f2(x,y).numpy()

# %% [markdown]
# Calculate gradient in Tensorflow
#
# by using GradientTape() as tape and tape.watch(a)

# %%
a=tf.random.normal(shape=(2,2))
b=tf.random.normal(shape=(2,2))

with tf.GradientTape() as tape:
    tape.watch(a)
    c=tf.sqrt(tf.square(a)+tf.square(b))
    dc_da=tape.gradient(c,a)
    print(dc_da)
# Out:
# tf.Tensor(
# [[-0.6685041   0.52978075]
#  [ 0.6608312  -0.23401457]], shape=(2, 2), dtype=float32)

# %%
a=tf.Variable(a)
with tf.GradientTape() as tape:
    c=tf.sqrt(tf.square(a)+tf.square(b))
    dc_da=tape.gradient(c,a)
    print(dc_da)
# Out:
# tf.Tensor(
# [[-0.6685041   0.52978075]
#  [ 0.6608312  -0.23401457]], shape=(2, 2), dtype=float32)

# %%
with tf.GradientTape() as outer_tape:
    with tf.GradientTape() as inner_tape:
        c=tf.sqrt(tf.square(a)+tf.square(b))
        dc_da=inner_tape.gradient(c,a)
    d2c_da2=outer_tape.gradient(dc_da,a)
    print(d2c_da2)
# Out:
# tf.Tensor(
# [[0.62749857 1.0227001 ]
#  [0.43828866 0.6003866 ]], shape=(2, 2), dtype=float32)
